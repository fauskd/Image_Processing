# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
from skimage import img_as_float

# %%
my_image = io.imread('monalisa.jpg')
plt.imshow(my_image)

# %%
print(my_image)
# Out:
# [[[116 124  73]
#   [118 126  75]
#   [119 127  76]
#   ...
#   [121 132  90]
#   [109 118  87]
#   [ 90  98  74]]
#
#  [[114 122  71]
#   [115 123  72]
#   [116 124  73]
#   ...
#   [123 134  92]
#   [111 120  89]
#   [ 91  99  75]]
#
#  [[117 124  72]
#   [119 126  74]
#   [119 128  75]
#   ...
#   [124 135  93]
#   [111 120  89]
#   [ 89  97  73]]
#
#  ...
#
#  [[108  80  68]
#   [101  77  65]
#   [ 82  61  56]
#   ...
#   [ 73  56  62]
#   [ 78  60  60]
#   [103  84  80]]
#
#  [[108  80  66]
#   [100  73  62]
#   [ 83  62  57]
#   ...
#   [ 74  61  71]
#   [ 71  56  61]
#   [ 98  83  86]]
#
#  [[111  82  66]
#   [ 96  69  58]
#   [ 84  65  61]
#   ...
#   [ 70  59  73]
#   [ 62  50  60]
#   [ 90  79  87]]]

# %%
np.max(my_image)
# Out:
# 251

# %%
np.min(my_image)
# Out:
# 0

# %%
my_float_image = img_as_float(my_image)
print(my_float_image.min(), my_float_image.max())
# plt.imshow(my_float_image)
my_float_image[:100,:100,:]= [255,0,0]
plt.imshow(my_float_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.0 0.984313725490196

# %%
my_float_image[:100,:100,:]= [255,255,0]
plt.imshow(my_float_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Using pillow for image loading

# %%
my_float_image[:100,:100,:]= [255,255,255]
plt.imshow(my_float_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = Image.open('monalisa.jpg')

# %%
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x13A8F2620>

# %%
plt.imshow(img)

# %%
arr = np.asarray(img)

# %%
print(arr)
# Out:
# [[[116 124  73]
#   [118 126  75]
#   [119 127  76]
#   ...
#   [121 132  90]
#   [109 118  87]
#   [ 90  98  74]]
#
#  [[114 122  71]
#   [115 123  72]
#   [116 124  73]
#   ...
#   [123 134  92]
#   [111 120  89]
#   [ 91  99  75]]
#
#  [[117 124  72]
#   [119 126  74]
#   [119 128  75]
#   ...
#   [124 135  93]
#   [111 120  89]
#   [ 89  97  73]]
#
#  ...
#
#  [[108  80  68]
#   [101  77  65]
#   [ 82  61  56]
#   ...
#   [ 73  56  62]
#   [ 78  60  60]
#   [103  84  80]]
#
#  [[108  80  66]
#   [100  73  62]
#   [ 83  62  57]
#   ...
#   [ 74  61  71]
#   [ 71  56  61]
#   [ 98  83  86]]
#
#  [[111  82  66]
#   [ 96  69  58]
#   [ 84  65  61]
#   ...
#   [ 70  59  73]
#   [ 62  50  60]
#   [ 90  79  87]]]

# %% [markdown]
# # using matplotlib for loading image

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('monalisa.jpg')
print(img)
# Out:
# [[[116 124  73]
#   [118 126  75]
#   [119 127  76]
#   ...
#   [121 132  90]
#   [109 118  87]
#   [ 90  98  74]]
#
#  [[114 122  71]
#   [115 123  72]
#   [116 124  73]
#   ...
#   [123 134  92]
#   [111 120  89]
#   [ 91  99  75]]
#
#  [[117 124  72]
#   [119 126  74]
#   [119 128  75]
#   ...
#   [124 135  93]
#   [111 120  89]
#   [ 89  97  73]]
#
#  ...
#
#  [[108  80  68]
#   [101  77  65]
#   [ 82  61  56]
#   ...
#   [ 73  56  62]
#   [ 78  60  60]
#   [103  84  80]]
#
#  [[108  80  66]
#   [100  73  62]
#   [ 83  62  57]
#   ...
#   [ 74  61  71]
#   [ 71  56  61]
#   [ 98  83  86]]
#
#  [[111  82  66]
#   [ 96  69  58]
#   [ 84  65  61]
#   ...
#   [ 70  59  73]
#   [ 62  50  60]
#   [ 90  79  87]]]

# %%
plt.imshow(img)
plt.colorbar()

# %% [markdown]
# # Using Scikit for image loading

# %%
from skimage import io, img_as_float, img_as_ubyte
import matplotlib.pyplot as plt

# %%
img = io.imread('monalisa.jpg')
print(img)
# Out:
# [[[116 124  73]
#   [118 126  75]
#   [119 127  76]
#   ...
#   [121 132  90]
#   [109 118  87]
#   [ 90  98  74]]
#
#  [[114 122  71]
#   [115 123  72]
#   [116 124  73]
#   ...
#   [123 134  92]
#   [111 120  89]
#   [ 91  99  75]]
#
#  [[117 124  72]
#   [119 126  74]
#   [119 128  75]
#   ...
#   [124 135  93]
#   [111 120  89]
#   [ 89  97  73]]
#
#  ...
#
#  [[108  80  68]
#   [101  77  65]
#   [ 82  61  56]
#   ...
#   [ 73  56  62]
#   [ 78  60  60]
#   [103  84  80]]
#
#  [[108  80  66]
#   [100  73  62]
#   [ 83  62  57]
#   ...
#   [ 74  61  71]
#   [ 71  56  61]
#   [ 98  83  86]]
#
#  [[111  82  66]
#   [ 96  69  58]
#   [ 84  65  61]
#   ...
#   [ 70  59  73]
#   [ 62  50  60]
#   [ 90  79  87]]]

# %%
img_float = img_as_float(img)
print(img_float)
plt.imshow(img_float)
# Out:
# [[[0.45490196 0.48627451 0.28627451]
#   [0.4627451  0.49411765 0.29411765]
#   [0.46666667 0.49803922 0.29803922]
#   ...
#   [0.4745098  0.51764706 0.35294118]
#   [0.42745098 0.4627451  0.34117647]
#   [0.35294118 0.38431373 0.29019608]]
#
#  [[0.44705882 0.47843137 0.27843137]
#   [0.45098039 0.48235294 0.28235294]
#   [0.45490196 0.48627451 0.28627451]
#   ...
#   [0.48235294 0.5254902  0.36078431]
#   [0.43529412 0.47058824 0.34901961]
#   [0.35686275 0.38823529 0.29411765]]
#
#  [[0.45882353 0.48627451 0.28235294]
#   [0.46666667 0.49411765 0.29019608]
#   [0.46666667 0.50196078 0.29411765]
#   ...
#   [0.48627451 0.52941176 0.36470588]
#   [0.43529412 0.47058824 0.34901961]
#   [0.34901961 0.38039216 0.28627451]]
#
#  ...
#
#  [[0.42352941 0.31372549 0.26666667]
#   [0.39607843 0.30196078 0.25490196]
#   [0.32156863 0.23921569 0.21960784]
#   ...
#   [0.28627451 0.21960784 0.24313725]
#   [0.30588235 0.23529412 0.23529412]
#   [0.40392157 0.32941176 0.31372549]]
#
# ...

# %% [markdown]
# # using opencv for image processing

# %%
pip install open-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('monalisa.jpg')
plt.imshow(img)

# %% [markdown]
# # for grey image

# %%
img = cv2.imread('monalisa.jpg',0)
plt.imshow(img)

# %% [markdown]
# # for color image

# %%
img = cv2.imread('monalisa.jpg',1)
plt.imshow(img)

# %% [markdown]
# # use opencv for visualizing

# %%
grey_img = cv2.imread('monalisa.jpg',0)
color_img = cv2.imread('monalisa.jpg',1)
cv2.imshow('color_img', color_img)
cv2.imshow('grey_img', grey_img)
cv2.waitKey(1000)
cv2.destroyAllWindows()

# %% [markdown]
# # using czifile

# %%
import czifile

# %%
img = czifile.imread('monalisa.jpg')
print(img.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 img = czifile.imread('monalisa.jpg')
#       2 print(img.shape)
#
# File ~/anaconda3/lib/python3.10/site-packages/czifile/czifile.py:220, in imread(filename, *args, **kwargs)
#     214 def imread(filename, *args, **kwargs):
#     215     """Return image data from CZI file as numpy array.
#     216
#     217     'args' and 'kwargs' are arguments to the CziFile.asarray function.
#     218
#     219     """
# --> 220     with CziFile(filename) as czi:
#     221         result = czi.asarray(*args, **kwargs)
#     222     return result
#
# File ~/anaconda3/lib/python3.10/site-packages/czifile/czifile.py:266, in CziFile.__init__(self, arg, multifile, filesize, detectmosaic)
#     264 try:
#     265     if self._fh.read(10) != b'ZISRAWFILE':
# --> 266         raise ValueError('not a CZI file')
# ...

# %%
import cv2
import glob

# %%
path = "ImageProcessing/test_images/*"

# %%
for file in glob.glob(path):
    print(file)
    a = cv2.imread(file)
    print(a)
    c = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
    cv2.imshow("color_image", c)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
